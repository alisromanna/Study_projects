# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1">Предобработка данных</a></span></li><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии-2">Функции для расчёта и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функции-для-вычисления-значений-метрик" data-toc-modified-id="Функции-для-вычисления-значений-метрик-2.1">Функции для вычисления значений метрик</a></span><ul class="toc-item"><li><span><a href="#Создание-профилей-пользователей" data-toc-modified-id="Создание-профилей-пользователей-2.1.1">Создание профилей пользователей</a></span></li><li><span><a href="#Расчет-коэффициента-удержания" data-toc-modified-id="Расчет-коэффициента-удержания-2.1.2">Расчет коэффициента удержания</a></span></li><li><span><a href="#Расчет-конверсии" data-toc-modified-id="Расчет-конверсии-2.1.3">Расчет конверсии</a></span></li><li><span><a href="#Расчет-LTV-и-ROI" data-toc-modified-id="Расчет-LTV-и-ROI-2.1.4">Расчет LTV и ROI</a></span></li></ul></li><li><span><a href="#Функции-для-построения-графиков" data-toc-modified-id="Функции-для-построения-графиков-2.2">Функции для построения графиков</a></span><ul class="toc-item"><li><span><a href="#Визуализация-удержания" data-toc-modified-id="Визуализация-удержания-2.2.1">Визуализация удержания</a></span></li><li><span><a href="#Визуализация-конверсии" data-toc-modified-id="Визуализация-конверсии-2.2.2">Визуализация конверсии</a></span></li><li><span><a href="#Визуализация-LTV-и-ROI" data-toc-modified-id="Визуализация-LTV-и-ROI-2.2.3">Визуализация LTV и ROI</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-3.1">Профили пользователей</a></span><ul class="toc-item"><li><span><a href="#Разбивка-по-странам" data-toc-modified-id="Разбивка-по-странам-3.1.1">Разбивка по странам</a></span></li><li><span><a href="#Разбивка-по-устройствам" data-toc-modified-id="Разбивка-по-устройствам-3.1.2">Разбивка по устройствам</a></span></li><li><span><a href="#Разбивка-по-каналам-привлечения" data-toc-modified-id="Разбивка-по-каналам-привлечения-3.1.3">Разбивка по каналам привлечения</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-3.2">Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов-на-маркетинг" data-toc-modified-id="Общая-сумма-расходов-на-маркетинг-3.2.1">Общая сумма расходов на маркетинг</a></span></li><li><span><a href="#Распределение-трат-по-источникам" data-toc-modified-id="Распределение-трат-по-источникам-3.2.2">Распределение трат по источникам</a></span></li><li><span><a href="#Динамика-изменения-расходов-во-времени" data-toc-modified-id="Динамика-изменения-расходов-во-времени-3.2.3">Динамика изменения расходов во времени</a></span></li><li><span><a href="#Средняя-стоимость-привлечения-одного-пользователя-(CAC)-из-каждого-источника" data-toc-modified-id="Средняя-стоимость-привлечения-одного-пользователя-(CAC)-из-каждого-источника-3.2.4">Средняя стоимость привлечения одного пользователя (CAC) из каждого источника</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы" data-toc-modified-id="Окупаемость-рекламы-3.3">Окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#LTV,-CAC-и-ROI" data-toc-modified-id="LTV,-CAC-и-ROI-3.3.1">LTV, CAC и ROI</a></span></li><li><span><a href="#Конверсия-и-удержание" data-toc-modified-id="Конверсия-и-удержание-3.3.2">Конверсия и удержание</a></span></li><li><span><a href="#По-устройствам" data-toc-modified-id="По-устройствам-3.3.3">По устройствам</a></span></li><li><span><a href="#По-странам" data-toc-modified-id="По-странам-3.3.4">По странам</a></span></li><li><span><a href="#По-рекламным-каналам" data-toc-modified-id="По-рекламным-каналам-3.3.5">По рекламным каналам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-каналам" data-toc-modified-id="Конверсия-и-удержание-по-каналам-3.3.6">Конверсия и удержание по каналам</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4">Вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Маркетинговая аналитика и анализ убытков развлекательного приложения Procrastinate Pro+
#
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
# **Цель исследования**: разобраться в причинах и помочь компании выйти в плюс.
#
# Предстоит изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.
#
# **Данные** о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.

# %% [markdown]
# ## Предобработка данных
# Загружаем необходимые для работы библиотеки и исходные данные.

# %%
# импортируем необходимые библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# загружаем исходные данные
visits, orders, costs = (
        pd.read_csv('visits_info_short.csv'),  # визиты
        pd.read_csv('orders_info_short.csv'),  # заказы
        pd.read_csv('costs_info_short.csv'),  # расходы на рекламу
)

print('Данные загружены.')
# Out:
# Данные загружены.

# %% [markdown]
# Исследуем доступные для анализа данные. Выведем информацию о датасетах и первые пять строк.
#
# Начнем с таблицы сессий пользователей `visits`.

# %%
visits.info()
visits.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# ...

# %% [markdown]
# Исследуем таблицу с заказами пользователей `orders`.

# %%
orders.info()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# И посмотрим затраты на рекламу в таблице `costs`.

# %%
costs.info()
costs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# Пропусков в таблицах не обнаружено. Проверим их на наличие дубликатов.

# %%
print('Дубликаты в таблице "visits":', visits.duplicated().sum())
print('Дубликаты в таблице "orders":', orders.duplicated().sum())
print('Дубликаты в таблице "costs":', costs.duplicated().sum())
# Out:
# Дубликаты в таблице "visits": 0
# Дубликаты в таблице "orders": 0
# Дубликаты в таблице "costs": 0

# %% [markdown]
# Дубликатов также не обнаружено. Приведем названия столбцов к стандартному виду (без пробелов и к нижнему регистру).

# %%
# приведем названия столбцов к стандартному виду
visits = visits.rename(columns={'User Id' : 'user_id', 
                                'Session Start' : 'session_start', 
                                'Session End' : 'session_end'})

orders = orders.rename(columns={'User Id' : 'user_id',
                                'Event Dt' : 'event_dt'})

visits.columns= visits.columns.str.lower()
orders.columns= orders.columns.str.lower()
costs.columns= costs.columns.str.lower()

# %% [markdown]
# Данные о времени во всех таблицах приведем к нужному формату.

# %%
# преобразование данных о времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt'])

# %% [markdown]
# Итак, заменили имена столбцов на стандартные, поменяли, где необходимо, тип данных. Дубликатов и пропусков не обнаружено.
# Доступны данные о 310 тысячах визитов, 40 тысячах заказов и  почти 2 тысячи записей о рекламных расходах в период с 1 мая по 27 октября 2019 года.

# %% [markdown]
# ## Функции для расчёта и анализа LTV, ROI, удержания и конверсии
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.
#
# ### Функции для вычисления значений метрик
#
# #### Создание профилей пользователей
# Функция `get_profiles` создает пользовательские профили для когортного анализа.
#
# Ее аргументы:
# - `sessions` - данные о пользовательских сессиях,
# - `orders` - заказах пользователей,
# - `ad_costs` - затратах на рекламу,
# - `event_names` - список событий (опционально, по умолчанию это пустой список).
#
# Ход работы функции:
# - создаем профили пользователей `profiles`: идентификатор пользователя, дата первого посещения, совершил ли пользователь покупку;
# - группируем новых пользователей по дате и каналу привлечения в таблице `new_users`;
# - объединяем таблицы `new_users` и `ad_costs` с затратами на рекламу и рассчитываем стоимость привлечения одного пользователя (CAC);
# - объединяем новые таблицы в итоговой таблице `profiles`.
#
# В результате получаем таблицу `profiles` со столбцами:
# - `user_id` - идентификатор пользователя,
# - `first_ts` - дата и время первого посещения,
# - `channel` - канал привлечения,
# - `device` - устройство пользователя
# - `region` - регион пользователя,
# - `dt` - дата первого посещения
# - `month` - месяц первого посещения,
# - `payer` - признак совершения покупки,
# - `acquisition_cost` - стоимость привлечения пользователя.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs['dt'] = pd.to_datetime(ad_costs['dt']).dt.date
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### Расчет коэффициента удержания
# Функция `get_retention` рассчитывает коэффициент удержания. Чтобы получить коэффициент удержания, нужно количество активных пользователей на текущий день разделить на количество активных пользователей на первый день в каждой когорте.
#
# Ее аргументы:
# - `profiles` - профили пользователей,
# - `sessions` - данные о пользовательских сессиях,
# - `observation_date` - момент анализа,
# - `horizon_days` - горизонт анализа (в днях),
# - `dimensions` - признак(и) группировки (по умолчанию признак совершения покупки),
# - `ignore_horizon` - опция "игнорировать горизонт анализа", по умолчанию `False`.
#
# Ход работы функции:
# - фильтруем пользователей по дате и исключаем тех, кто не "дожил" до горизонта анализа,
# - собираем в одну таблицу `result_raw` профили пользователей, их сессии, здесь же расссчитываем лайфтайм каждого пользователя для каждой сессии,
# - строим таблицу удержания `result`: сводная таблица, где названия столбцов – лайфтайм, в ячейках количество уникальных идентификаторов пользователей, а названия строк - признак совершения покупки и/или дата первого посещения (`dimensions`),
# - в отдельной таблице `cohort_sizes` вычисляем размеры когорт и объединяем ее с таблицей удержания,
# - делим каждую ячейку таблицы удержания на соответствующий размер когорты.
#
# Результат работы функции:
# - "сырые" данные для расчета `result_raw`,
# - таблица удержания `result_grouped`,
# - таблица динамики удержания `result_in_time`.

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return (
        result_raw, 
        result_grouped, 
        result_in_time
           )

# %% [markdown]
# #### Расчет конверсии
# Функция `get_conversion` во многом похожа на функции расчета коэффициента удержания, только здесь важно не количество активных пользователей, а количество первых покупок.
#
# Ее аргументы:
# - `profiles` - профили пользователей,
# - `purchases` - данные о покупках,
# - `observation_date` - момент анализа,
# - `horizon_days` - горизонт анализа (в днях),
# - `dimensions` - признак(и) группировки данных,
# - `ignore_horizon` - опция "игнорировать горизонт анализа", по умолчанию `False`.
#
# Ход работы функции:
# - фильтруем пользователей по дате, оставляем только "доживших" до горизонта анализа,
# - данные о покупках добавляем в профили пользователей,
# - считаем лайфтайм для каждой покупки,
# - строим таблицу конверсии: сводную таблицу, где названия столбцов – лайфтайм, в ячейках количество уникальных идентификаторов пользователей, а названия строк - дата первого посещения (`dimensions`),
# - считаем сумму с накоплением для каждой строки таблицы конверсии,
# - вычисляем размеры когорт, добавляем их в общую таблицу и делим каждую ячейку таблицы конверсии на соответствующий размер когорты.
#
# Результат работы функции:
# - "сырые" данные для расчетов `result_raw`,
# - таблица конверсии `result_grouped`,
# - таблица динамики конверсии `result_in_time`.

# %%
# функция для расчета конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return (
        result_raw, 
        result_grouped, 
        result_in_time
    )

# %% [markdown]
# #### Расчет LTV и ROI
# Функция `get_ltv` для расчета значений юнит-экономики LTV и ROI.
#
# Ее аргументы:
# - `profiles` - профили пользователей,
# - `purchases` - данные о покупках,
# - `observation_date` - момент анализа,
# - `horizon_days` - горизонт анализа (в днях),
# - `dimensions` - признак(и) группировки данных,
# - `ignore_horizon` - опция "игнорировать горизонт анализа", по умолчанию `False`.
#
# Ход работы функции:
# - фильтруем пользователей по дате, оставляем только "доживших" до горизонта анализа,
# - добавляем в профили данные о покупках, рассчитываем лайфтайм пользователя для каждой покупки,
# - группируем данные,
# - находим сумму выручки и размеры когорт,
# - считаем LTV (сумму выручки делим на размер когорты),
# - находим средний CAC по параметрам `dimensions` и считаем ROI: делим LTV на CAC.
#
# Результат работы функции:
# - сырые данные, `result_raw`,
# - таблица LTV, `result_grouped`,
# - таблица динамики LTV, `result_in_time`,
# - таблица ROI, `roi_grouped`,
# - таблица динамики ROI, `roi_in_time`.

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функции для построения графиков

# %% [markdown]
# Напишем небольшую функцию `filter_data` для сглаживания наших линейных графиков путем применения оконной функции и расчета скользящего среднего.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### Визуализация удержания
#
# Функция `plot_retention` строит сразу 4 графика:
# - удержание в зависимости от лайфтайма для платящих и неплатящих пользователей,
# - динамика удержания на n-й день (задается через параметр `horizon`) для платящих и неплатящих пользователей по дате привлечения.
#
# Ее аргументы:
# - `retention` - таблица удержания,
# - `retention_history` - таблица динамики удержания,
# - `horizon` - горизонт анализа,
# - `window` - окно сглаживания графика в днях (по умолчанию равно 7).

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Визуализация конверсии
# Функция `plot_conversion` строит два графика: конверсия пользователей в зависимости от лайфтайма и динамика конверсии пользователей на n-й день (задается через параметр `horizon`) по дате привлечения.
#
# Ее аргументы:
# - `conversion` - таблица конверсии,
# - `conversion_history` - таблица динамики конверсии,
# - `horizon` - горизонт анализа,
# - `window` - окно сглаживания графика в днях (по умолчанию равно 7).

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Визуализация LTV и ROI
# Функция `plot_ltv_roi` строит 5 графиков:
# - кривые LTV,
# - динамика LTV,
# - динамика CAC,
# - кривые ROI,
# - динамика ROI.
#
# Ее аргументы:
# - `ltv` - таблица LTV,
# - `ltv_history` - таблица динамики LTV,
# - `roi` - таблица ROI,
# - `roi_history` - таблица динамики ROI,
# - `horizon` - горизонт анализа,
# - `window` - окно сглаживания графика в днях (по умолчанию равно 7).

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей

# %% [markdown]
# Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# определим минимальную и максимальную даты привлечения пользователей
print('Минимальная дата привлечения пользователей:', profiles['dt'].min())
print('Максимальная дата привлечения пользователей:', profiles['dt'].max())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# Составили профили пользователей с их уникальными номерами, датой первого посещения, канала привлечения, утсройства, региона, датой и месяца посещения, наличие или отсутствие покупки, стоимость привлечения. Минимальная дата привлечения – 1 мая 2019 года, максимальная – 27 октября 2019 года.
#
# Таким образом, даты привлечения пользователей совпадают с условиями проекта (ТЗ).

# %% [markdown]
# #### Разбивка по странам
# Узнаем, из каких стран приходят пользователи приложения. Выведем все уникальные значения столбца `region`.

# %%
# из каких стран пользователи приходят в приложение
print(profiles['region'].unique())
# Out:
# ['United States' 'France' 'Germany' 'UK']

# %% [markdown]
# Выясним на какую страну приходится больше всего платящих пользователей.
# Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
# группируем пользователей по регионам
profiles_region = (
    profiles
    .groupby('region')
    .agg({'user_id' : 'nunique', 
          'payer' : ['sum', 'mean']})
    .reset_index()
)

profiles_region.columns = ['Регион', 'Пользователи', 'Платящие пользователи', '% платящих']

profiles_region['% платящих'] = round(profiles_region['% платящих'] * 100, 1)

profiles_region.sort_values(by = 'Пользователи', ascending = False)
# Out:
#           Регион  Пользователи  Платящие пользователи  % платящих
# 3  United States        100002                   6902         6.9
# 2             UK         17575                    700         4.0
# 0         France         17450                    663         3.8
# 1        Germany         14981                    616         4.1

# %%
# покажем распределение пользователей по регионам и доли платящих пользователей (у графиков общая ось Y)

fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10,4))
fig.suptitle('Распределение пользователей по регионам')

sns.barplot(ax=ax[0], 
            data=profiles_region,
            x='Пользователи', 
            y='Регион', )
ax[0].set_title('Общее количество пользователей')

sns.barplot(ax=ax[1], 
            data=profiles_region,
            x='% платящих', 
            y='Регион', )
ax[1].set_title('Доля платящих пользователей');

# %% [markdown]
# Приложением пользуются клиенты из США, Франции, Германии и Великобритании.
# Больше всего пользователей из США (100 тысяч), в этой же стране наибольший процент платящих пользователей – почти 7%. Великобритания и Франция находятся на 2 и 3 местах с очень близкими показателями. На последнем месте по количеству пользователей Германия, хотя доля платящих пользователей там немного выше, чем в Великобритании и Франции.

# %% [markdown]
# #### Разбивка по устройствам

# %% [markdown]
# Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
print(profiles['device'].unique())
# Out:
# ['Mac' 'iPhone' 'PC' 'Android']

# %%
# группируем пользователей по типу их устройств
profiles_device = (
    profiles
    .groupby('device')
    .agg({'user_id' : 'nunique', 
          'payer' : ['sum', 'mean']})
    .reset_index()
)

profiles_device.columns = ['Устройство', 
                           'Пользователи', 
                           'Платящие пользователи', 
                           '% платящих']

profiles_device['% платящих'] = round(profiles_device['% платящих'] * 100, 1)

profiles_device.sort_values(by = 'Пользователи', ascending = False)
# Out:
#   Устройство  Пользователи  Платящие пользователи  % платящих
# 3     iPhone         54479                   3382         6.2
# 0    Android         35032                   2050         5.9
# 2         PC         30455                   1537         5.0
# 1        Mac         30042                   1912         6.4

# %%
# покажем распределение пользователей по типам устройств и доли платящих пользователей (у графиков общая ось Y)

fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10,4))
fig.suptitle('Распределение пользователей по типам устройств')

sns.barplot(ax=ax[0], 
            data=profiles_device,
            x='Пользователи', 
            y='Устройство', )
ax[0].set_title('Общее количество пользователей')

sns.barplot(ax=ax[1], 
            data=profiles_device,
            x='% платящих', 
            y='Устройство', )
ax[1].set_title('Доля платящих пользователей');

# %% [markdown]
# Больше всего клиентов, пользующихся айфонами (у них же почти самый высоких % платящих пользователей), меньше всего – с устройствами Мас. При этом клиенты с Mac имеют наибольший процент платящих. Меньше всего платящих клиентов, пользующихся РС.

# %% [markdown]
# #### Разбивка по каналам привлечения

# %% [markdown]
# Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Построим таблицу и график, отражающие количество пользователей и долю платящих для каждого канала привлечения.

# %%
print(profiles['channel'].unique())
# Out:
# ['FaceBoom' 'organic' 'AdNonSense' 'YRabbit' 'MediaTornado'
#  'RocketSuperAds' 'LeapBob' 'TipTop' 'WahooNetBanner' 'OppleCreativeMedia'
#  'lambdaMediaAds']

# %%
# группируем пользователей по каналам привлечения

profiles_channel = (
    profiles
    .groupby('channel')
    .agg({'user_id' : 'nunique', 
          'payer' : ['sum', 'mean']})
    .reset_index()
)


profiles_channel.columns = ['Канал привлечения', 
                            'Пользователи', 
                            'Платящие пользователи', 
                            '% платящих']

profiles_channel['% платящих'] = round(profiles_channel['% платящих'] * 100, 1)

profiles_channel = profiles_channel.sort_values(by='Пользователи', 
                                                ascending=False)
profiles_channel
# Out:
#      Канал привлечения  Пользователи  Платящие пользователи  % платящих
# 10             organic         56439                   1160         2.1
# 1             FaceBoom         29144                   3557        12.2
# 6               TipTop         19561                   1878         9.6
# 4   OppleCreativeMedia          8605                    233         2.7
# 2              LeapBob          8553                    262         3.1
# 7       WahooNetBanner          8553                    453         5.3
# 5       RocketSuperAds          4448                    352         7.9
# 3         MediaTornado          4364                    156         3.6
# 8              YRabbit          4312                    165         3.8
# 0           AdNonSense          3880                    440        11.3
# 9       lambdaMediaAds          2149                    225        10.5

# %%
# покажем распределение пользователей по каналам и доли платящих пользователей (у графиков общая ось Y)

fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10,4))
fig.suptitle('Распределение пользователей по каналам привлечения')

sns.barplot(ax=ax[0], 
            data=profiles_channel,
            x='Пользователи', 
            y='Канал привлечения', )
ax[0].set_title('Общее количество пользователей')

sns.barplot(ax=ax[1], 
            data=profiles_channel,
            x='% платящих', 
            y='Канал привлечения', )
ax[1].set_title('Доля платящих пользователей');

# %% [markdown]
# Больше всего (56 тысяч) в приложении органических, то есть бесплатных пользователей, но вот доля платящих среди них – самая низкая (2%). Наибольший процент платящих клиентов (12%) пришел из канала FaceBoom, они же занимают второе место по численности среди всех пользователей (29 тысяч). Меньше всего пользователей приходит из канала  lambdaMediaAds, но среди них высокий процент платящих пользователей. Кроме "органических" клиентов, меньше всего платящих среди тех, кто пришли с каналов OppleCreativeMedia, LeapBob, MediaTornado, YRabbit.

# %% [markdown]
# ### Маркетинг
#
# - Посчитаем общую сумму расходов на маркетинг.
# - Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.
# - Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используем профили пользователей.

# %% [markdown]
# #### Общая сумма расходов на маркетинг

# %% [markdown]
# Посчитаем общую сумму всех затрат на маркетинг за исследуемый период.

# %%
# посчитаем общую сумму расходов на маркетинг
costs['costs'].sum().astype('int')
# Out:
# 105497

# %% [markdown]
# Таким образом, в период с 1 мая по 27 октября 2019 года общая сумма затрат на рекламу составила 105 тысяч $.

# %% [markdown]
# #### Распределение трат по источникам

# %% [markdown]
# Узнаем, сколько денег было потрачено на рекламу в каждом из используемых источников привлечения новых пользователей. Соеберм данные в таблице `costs_channel` и покажем получившийся результат на гистограмме.

# %%
# сколько денег потрачено на каждый источник
costs_channel = (
    costs
    .groupby('channel')
    .agg({'costs' : 'sum'})
    .reset_index()
)

costs_channel.columns = ['Канал привлечения', 
                         'Затраты на рекламу, $']

costs_channel = costs_channel.sort_values(by='Затраты на рекламу, $', 
                                          ascending=False)
costs_channel
# Out:
#     Канал привлечения  Затраты на рекламу, $
# 6              TipTop               54751.30
# 1            FaceBoom               32445.60
# 7      WahooNetBanner                5151.00
# 0          AdNonSense                3911.25
# 4  OppleCreativeMedia                2151.25
# 5      RocketSuperAds                1833.00
# 2             LeapBob                1797.60
# 9      lambdaMediaAds                1557.60
# 3        MediaTornado                 954.48
# 8             YRabbit                 944.22

# %%
# распределение рекламных трат по каналам привлечения
sns.barplot(
    data=costs_channel,
    x='Затраты на рекламу, $',
    y='Канал привлечения'
)
plt.title('Распределение затрат на маркетинг по каналам/источникам');

# %% [markdown]
# Больше всего было потрачено на рекламу на канале TipTop (55 тысяч), несколько меньше – на канале FaceBoom (32 тысячи). Траты на остальные каналы в разы меньше. Меньше всего было потрачено на каналы MediaTornado и YRabbit.

# %% [markdown]
# #### Динамика изменения расходов во времени

# %% [markdown]
# Исследуем динамику рекламных затрат по неделям и месяцам в разбивке по каналам привлечения. В таблице маркетинговых затрат `costs` добавим два новых столбца с неделей и месяцем. Затем создадим две сводные таблицы с группировкой по каналам и неделе `costs_history_week` и с группировкой по каналам и месяцам `costs_history_month`.

# %%
# добавим столбцы с номерами недели и месяца
costs['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs['month'] = pd.to_datetime(costs['dt']).dt.month

# построим сводные таблицы с распределением трат по неделям
costs_history_week = (
    costs.pivot_table(index=['week'], 
                      columns='channel', 
                      values='costs', 
                      aggfunc='sum')
)
costs_history_week.head()
# Out:
# channel  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# week
# 18           211.05     535.7    16.80         38.64               24.00
# 19           273.00     750.2    31.71         61.68               34.50
# 20           265.65     755.7    26.67         59.04               27.50
# 21           266.70     722.7    26.67         50.16               34.25
# 22           202.65    1208.9    65.52         36.96               81.75
#
# channel  RocketSuperAds  TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# week
# 18               99.450   347.0            49.2     52.2            81.6
# 19              139.230   470.0            92.4     75.9           103.2
# 20              138.060   454.0            90.0     69.3            90.4
# 21              131.040   801.8            79.2     65.4           119.2
# 22               97.695  1421.2           179.4     49.8            83.2

# %%
# построим сводные таблицы с распределением трат по месяцам
costs_history_month = (
    costs.pivot_table(index=['month'], 
                      columns='channel', 
                      values='costs', 
                      aggfunc='sum')
)
costs_history_month.head()
# Out:
# channel  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# month
# 5           1169.70    3524.4   140.28        238.56              169.75
# 6            538.65    5501.1   314.58        138.00              370.00
# 7            504.00    5294.3   313.53        138.48              366.50
# 8            579.60    6274.4   369.81        154.56              439.25
# 9            581.70    6114.9   343.98        144.72              427.75
#
# channel  RocketSuperAds   TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# month
# 5               577.980   2981.0           418.8   299.70           458.4
# 6               325.715   6675.6           921.0   106.20           199.2
# 7               252.070   8410.2           851.4    97.38           219.2
# 8               253.110  11202.0          1040.4   124.74           220.0
# 9               218.400  13232.5           977.4   152.79           247.2

# %% [markdown]
# Динамику изменения маркетинговых расходов по месяцам и неделям покажем на графиках.

# %%
# визуализируем траты по месяцам и неделям

plt.figure(figsize=(20, 6))  # задаём размер сетки


costs_history_week.plot(
    grid=True,
    ax = plt.subplot(1, 2, 1)
)
plt.legend()
plt.xlabel('Номер недели')
plt.title('Динамика изменения расходов по неделям')


costs_history_month.plot(
    grid=True,
    ax = plt.subplot(1, 2, 2)
)
plt.legend()
plt.xlabel('Номер месяца')
plt.title('Динамика изменения расходов по месяцам');

# %% [markdown]
# Траты на большинство (менее дорогих) каналов не менялись со временем, за исключением двух самых дорогих каналов привлечения – TipTop и FaceBoom. В целом, затраты на них постоянно увеличивались, макимальное увеличение трат было на канал TipTop.

# %% [markdown]
# #### Средняя стоимость привлечения одного пользователя (CAC) из каждого источника

# %% [markdown]
# Для каждого канала привлечения рассчитаем среднюю стоимость привлечения одного пользователя (САС). Для этого сгруппируем профили пользователей по каналам и посчитаем среднее значение `acquisition_cost`. У органических пользователей по определению стоимость привлечения равна нулю, так что их не считаем.

# %%
# рассчитаем среднюю стоимость привлечения одного пользователя из каждого источника
mean_cac = (
    profiles[profiles['channel'] != 'organic']
    .groupby('channel')
    .agg({'acquisition_cost' : 'mean'})
    .reset_index()
)

mean_cac.columns = ['Канал привлечения', 
                    'Средняя стоимость привлечения, $']

mean_cac = (
    mean_cac.sort_values(by = 'Средняя стоимость привлечения, $', 
                         ascending=False)
)
mean_cac
# Out:
#     Канал привлечения  Средняя стоимость привлечения, $
# 6              TipTop                          2.799003
# 1            FaceBoom                          1.113286
# 0          AdNonSense                          1.008054
# 9      lambdaMediaAds                          0.724802
# 7      WahooNetBanner                          0.602245
# 5      RocketSuperAds                          0.412095
# 4  OppleCreativeMedia                          0.250000
# 8             YRabbit                          0.218975
# 3        MediaTornado                          0.218717
# 2             LeapBob                          0.210172

# %% [markdown]
# Покажем распределение средней стоимости привлечения на графике.

# %%
# визуилизируем среднюю стоимость привлечения одного пользователя по каналам
sns.barplot(
    data=mean_cac,
    x='Средняя стоимость привлечения, $',
    y='Канал привлечения'
)
plt.title('Средняя стоимость привлечения пользователя по каналам/источникам');

# %% [markdown]
# Самая высокая стоимость привлечения также оказалась на каналах TipTop и FaceBoom (2.8 и 1.1 доллар соответственно). Для остальных каналов стоимость была 1$ и меньше. Самая низкая стоимость привлечения у каналов OppleCreativeMedia, YRabbit, MediaTornado, LeapBob.

# %% [markdown]
# ### Окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы. Считаем, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.
#
# - Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.
# - Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответим на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?

# %% [markdown]
# Установим момент и горизонт анализа данных. Предположим, что на календаре 1 ноября 2019 года, и зададим двух недельный горизонт анализа.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# #### LTV, CAC и ROI

# %% [markdown]
# Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.
# Для начала оценим общую ситуацию — посмотрим на окупаемость рекламы. Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`.

# %%
# в анализе не учитываем бесплатных пользователей, так как на них не было рекламных затрат
profiles = profiles.query('channel != "organic"')

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, 
    orders, 
    observation_date, 
    horizon_days
)

# строим графики
plot_ltv_roi(
    ltv_grouped, 
    ltv_history, 
    roi_grouped, 
    roi_history, 
    horizon_days
)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# - реклама не окупается,
# - если посмотреть на динамику ROI, то его значение на 14-й день лайфтайма стремительно снижается с мая по октябрь, так как расчтет привлечение пользователей,
# - CAC увеличивается, особенно резкое увеличение произошло в середине мая,
# - при этом показатель достаточно LTV стабилен, то есть дело не в ухудшении качества пользователей.
#
# Похоже, что проблема не в пользователях, а в увеличении затрат на рекламу.

# %% [markdown]
# #### Конверсия и удержание

# %% [markdown]
# Изучим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.
#
# Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим общую конверсию 

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, 
    orders, 
    observation_date, 
    horizon_days
)

plot_conversion(
    conversion_grouped, 
    conversion_history, 
    horizon_days
)

# %% [markdown]
# Конверсия хорошо растет в первые дни и в конце двухнедельного периода выходит на плато. Если смотреть в динамике, то конверсия сильно просела в середине мая, но в целом такое снижение вписывается с динамику сезонных колебаний.
#
# То же самое сделаем для коэффициента удержания, вызвав функции `get_retention()` и `plot_retention()`.

# %%
# смотрим общее удержание 

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, 
    visits, 
    observation_date, 
    horizon_days
)

plot_retention(
    retention_grouped, 
    retention_history, 
    horizon_days
)

# %% [markdown]
# Удержание как платящих, так и не платящих пользователей стремительно снижается с увеличением лайфтама. Удержание неплатящих пользователей почти равно нулю. Удержание платящих изначально было на не очень высокое (около 40%), а через две недели остается лишь около 10% пользователей. Показатель удержания на 14-й день также резко снизился в среедине мая, но затем восстановился. Динамика неплатящих пользователей около нуля, скорее всего, потому что приложение платное или большинство функци в нем только платные.
#
# Скорее всего, причина низкого удержания в какой-нибудь технической проблеме.

# %% [markdown]
# #### По устройствам
# Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# Начнём с разбивки по устройствам: передадим параметру `dimensions` столбец `device`.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, 
    orders, 
    observation_date, 
    horizon_days, 
    dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, 
    ltv_history, 
    roi_grouped, 
    roi_history, 
    horizon_days, 
    window=14
)

# %% [markdown]
# Вот что говорят графики:
# - реклама окупается на только на устройствах PC
# - ROI для всех устройств снижается
# - стоимость привлечения растет на всех устройствах, но особенно – на Mac и iPhone
# - стоимость привлечения всех клиентов резко выросла в мае
# - LTV в целом стабилен
#
# Обращаем внимание, что на пользователей Mac и iPhone приходятся самые большие и неокупаемые расходы на рекламу. Но окупается вообще только PC.

# %% [markdown]
# #### По странам
# Проанализируем окупаемость рекламы с разбивкой по странам. Также построим графики LTV и ROI и графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, 
    orders, 
    observation_date, 
    horizon_days, 
    dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, 
    ltv_history, 
    roi_grouped, 
    roi_history, 
    horizon_days, 
    window=14
)

# %% [markdown]
# - Реклама окупается везде кроме США
# - ROI клиентов США до мая, скорее всего, был сопоставим с остальными странами пока не рухнул в мае, и сейчас продолжает снижаться
# - динамика САС снизилась везде, кроме США – здесь взрывной рост с мая
# - при этом LTV клиентов из США стабильно выше, чем у всех остальных
#
# Таким образом, явно присутствует проблема с пользователями из США. Это качественные, "покупающие" клиенты, но слишком большие расходы на рекламу в этом регионе делают бизнес убыточным.

# %% [markdown]
# #### По рекламным каналам
# Проанализируем окупаемость рекламы с разбивкой по рекламным каналам (`channel`). Строим графики LTV и ROI, графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

# получаем таблицы ltv с разбивкой по каналам 
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, 
    orders, 
    observation_date, 
    horizon_days, 
    dimensions=dimensions
)
# визулизируем ltv, roi, cac в динамике
plot_ltv_roi(
    ltv_grouped, 
    ltv_history, 
    roi_grouped, 
    roi_history, 
    horizon_days, 
    window=14
)

# %% [markdown]
# Что можно сказать о каналах привлечения:
# - реклама не окупается на каналах TipTop, FaceBoom, lambdaMediaAds
# - хотя для каналов TipTop и lambdaMediaAds оказался наибольший LTV
# - для всех каналов, кроме TipTop показатель CAC стабилен во времени
# - у TipTop видны крупные ежемесячные увеличения расходов на рекламу
# - и обратим внимание на пик ROI на 14-й день по каналу YRabbit, видимо в летние месяцы удалось привлечь очень качественных пользователей (или на канале случился вирусный всплеск популярности приложения Procrastination Pro+)

# %% [markdown]
# Реклама приложения окупалась до мая 2019, потом "все сломалось" и общий ROI рухнул, реклама перестала окупаться. Проблемы были выявлены с клиентами из США (они стали намного дороже остальных клиентов), а также значительное (и похоже неэффективное) увеличение расходов на рекламу на канале TipTop. Канал FaceBoom приводит платящих пользователей, но они быстро уходят.
#
# Резкие изменения произошли в мае, поэтому имеет смысл посмотреть, что именно изменилось в компании в тот момент (новая версия приложения, изменения на каналах размещения рекламы и т.д.).

# %% [markdown]
# #### Конверсия и удержание по каналам
# Дополним исследование, сопоставив данные по конверсии и удержанию в разбивке по каналам. Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим конверсию с разбивкой по каналам
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, 
    orders, 
    observation_date, 
    horizon_days, 
    dimensions=dimensions
)

plot_conversion(
    conversion_grouped, 
    conversion_history, 
    horizon_days
)

# %% [markdown]
# Самая высокая конверсия оказалась у канала FaceBoom, а у самого дорогого TipTop конверсия средняя. Динамика конверсии пользователей на 14-й день в целом довольно стабильна. Таким образом, с конверсией действительно нет очевидных проблем.
#
# Видимо, проблема в удержании пользоваталей. Вызовем функции `get_retention()` и `plot_retention()`, чтобы рассчитать и отразить на графиках этот показатель.

# %%
# смотрим удержание с разбивкой по каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, 
    visits, 
    observation_date, 
    horizon_days, 
    dimensions=dimensions
)

plot_retention(
    retention_grouped, 
    retention_history, 
    horizon_days, 
    window=7
)

# %% [markdown]
# Сразу видно, насколько меньше удержание пользователей, пришедших с каналов AdNonSense и FaceBoom – оно изначально меньше и падает быстрее. C этих каналов приходят платящие, но низкокачественные клиенты – они быстро перестают пользоваться приложением. Зато со всех остальных каналов приходят примерно одинаковые клиенты, если сравнивать по показателям конверсии и удержания.

# %% [markdown]
# ### Вывод
#
# Низкие показатели удержания могут быть связаны с какими-то техническими проблемами, особенно на устройствах Mac и iPhone . В целом эти пользователи почти не отличаются от всех остальных, но для компании обходятся дороже. Есть вероятность, что Mac и iPhone просто более популярны в США и их "удорожание" косвенно связано со слишком большими расходами на рекламу в *TipTop* в США.
#
# Отделу маркетинга стоит более внимательно отнестись к рекламным расходам на привлечение пользователей из США по каналу *TipTop* пока не будет устранена основная причина низкого удержания: стоимость привлечения каждого пользователя лишь увеличивается, но в сочетании с низким удержанием это приносит только допольнительные расходы. Для повышения удержания пользователей из США можно попробовать ввести персонализированные UX-стратегии, e-mail рассылки, персональные рекомендации, push-уведомления.
#
# Дополнительного исследования требует канал *FaceBoom*. Несмотря на дороговизну рекламы, этот канал отличается высокой конверсией, проблема заключается в низком удержании. Стоит провести небольшое исследование именно этой части пользователей – почему они начинают пользоваться приложением, но потом уходят. Также на этом канале можно разместить информацию о промокодах для пользователей приложения или настроить более таргетированное привлечение, направленное на пользователей с определенными характеристиками. Кроме того, можно ввести поощрение пользователей за репосты в этом канале.
#
# Следует обратить внимание на другие каналы, например, *lambdaMediaAds, RocketSuperAds, WahooNetBanner*. Пользователи, пришедшие из этих каналов, стабильно окупаются и показывают хорошие результаты по конверсии и удержанию. Таким образом, рекламные расходы следует перераспределить в пользу каналов с более прибыльными и качественными пользователями. Для постоянных пользователей можно ввести систему "наград" и привеилегий.
